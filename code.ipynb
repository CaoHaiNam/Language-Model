# %%
import accelerate
import datasets
import evaluate
from datasets import load_dataset

import transformers
from transformers import (
    CONFIG_MAPPING,
    MODEL_FOR_MASKED_LM_MAPPING,
    AutoConfig,
    AutoModelForMaskedLM,
    AutoTokenizer,
    DataCollatorForLanguageModeling,
    HfArgumentParser,
    Trainer,
    TrainingArguments,
    is_torch_tpu_available,
    set_seed,
)
from transformers.trainer_utils import get_last_checkpoint
from transformers.utils import check_min_version, send_example_telemetry
from transformers.utils.versions import require_version

# %%
model = AutoModelForMaskedLM.from_pretrained('prajjwal1/bert-small')
# Out:
# Downloading (…)lve/main/config.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/116M [00:00<?, ?B/s]
# Some weights of the model checkpoint at prajjwal1/bert-small were not used when initializing BertForMaskedLM: ['cls.seq_relationship.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
tokenizer = AutoTokenizer.from_pretrained('prajjwal1/bert-small')
# Out:
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]

# %%
tokenizer.vocab_size
# Out:
# 30522

# %%
tokenizer.vocab
# Out:
# {'nigerian': 11884,
#  'banana': 15212,
#  '##iques': 19516,
#  '[unused804]': 809,
#  '華': 1942,
#  'rust': 18399,
#  'uncomfortable': 8796,
#  'outdated': 25963,
#  '##khan': 26370,
#  '[unused747]': 752,
#  '行': 1945,
#  '##phobia': 24920,
#  '##nage': 27031,
#  'susannah': 20471,
#  'successful': 3144,
#  'raked': 22438,
#  '##cript': 23235,
#  'waldo': 28806,
#  '##կ': 29774,
#  '1665': 27676,
#  'soaring': 23990,
#  '仮': 1761,
#  'hubert': 15346,
#  'walters': 19097,
#  'shapes': 10466,
#  '##δ': 29722,
#  'priesthood': 17911,
#  'slapping': 22021,
#  '##gen': 6914,
#  '##rians': 23543,
#  'joel': 8963,
#  '##ited': 17572,
#  'coloured': 11401,
#  'terminated': 12527,
#  'eileen': 20495,
#  'harmony': 9396,
#  'iced': 28248,
#  '##ₐ': 30089,
#  '##ep': 13699,
#  '##ify': 8757,
#  '##rona': 26788,
#  'kate': 5736,
#  '##ett': 6582,
#  'gripped': 9672,
#  'mae': 11530,
#  'massey': 21402,
#  'freeway': 10846,
#  'ankles': 15392,
#  'manifold': 19726,
#  '##rage': 24449,
#  'assume': 7868,
#  'lennon': 14294,
#  'offences': 18421,
#  'pointe': 26119,
#  'anterior': 15099,
#  'isn': 3475,
#  '[unused522]': 527,
#  'moscow': 4924,
#  '1782': 16890,
#  '[unused288]': 293,
#  'welch': 17939,
#  'circulation': 9141,
#  'barrie': 24953,
#  'mountain': 3137,
#  'bourne': 15803,
#  'several': 2195,
#  'key': 3145,
#  'individually': 14258,
#  'touchdowns': 10183,
#  '##inn': 23111,
#  'ত': 1362,
#  'conserve': 27749,
#  '##hong': 19991,
#  'sadness': 12039,
#  'ゆ': 1683,
#  'graders': 23256,
#  '##ssar': 25556,
#  '##sack': 25607,
#  'loretta': 28493,
#  'shrub': 15751,
#  '##ʑ': 29703,
#  '##y': 2100,
#  'neuroscience': 23700,
#  'hinted': 21795,
#  'sunrise': 13932,
#  'turquoise': 28653,
#  'lift': 6336,
#  'rig': 19838,
#  'տ': 1236,
#  '1740': 21757,
#  '117': 12567,
#  'fleets': 25515,
#  'huge': 4121,
#  '##mma': 14760,
#  'venture': 6957,
#  'woolf': 29572,
#  'longer': 2936,
#  'outnumbered': 21943,
#  'municipal': 4546,
#  'blackwell': 18776,
#  'chromosome': 16706,
#  'catalog': 12105,
#  '1950s': 4856,
#  '1646': 28783,
#  'amulet': 25087,
#  'subsidiaries': 20178,
#  'pioneer': 7156,
#  'useful': 6179,
#  'ト': 1714,
#  'accessory': 25339,
#  'quake': 27785,
#  'visited': 4716,
#  'atari': 18978,
#  'liquid': 6381,
#  'attitudes': 13818,
#  '₆': 1553,
#  '##tative': 27453,
#  'peoples': 7243,
#  'sweeping': 12720,
#  'ominous': 23504,
#  'contributes': 16605,
#  'leighton': 26873,
#  'hacking': 23707,
#  'disqualification': 27782,
#  'revived': 10570,
#  '197': 19975,
#  'aggression': 14974,
#  'trains': 4499,
#  'computers': 7588,
#  '##氵': 30420,
#  '##tson': 25656,
#  'eastward': 17318,
#  'reinforced': 11013,
#  '[unused432]': 437,
#  'puppet': 13997,
#  'gertrude': 18734,
#  '##formed': 29021,
#  '##urgent': 27176,
#  '##horn': 9769,
#  'resin': 24604,
#  '##tized': 23355,
#  '##？': 30520,
#  'sixth': 4369,
#  'mitch': 11857,
#  'chevrolet': 14724,
#  'lexie': 24123,
#  '##dent': 16454,
#  'gloves': 11875,
#  'fried': 13017,
#  'exhibiting': 22922,
#  'dummy': 24369,
#  'towers': 7626,
#  'showers': 23442,
#  'aquino': 24183,
#  'designer': 5859,
#  '##uy': 26230,
#  'near': 2379,
#  'vidhan': 28590,
#  '##vance': 21789,
#  'mastery': 26364,
#  'mum': 12954,
#  'organisations': 8593,
#  'brutally': 23197,
#  'katharine': 25739,
#  'work': 2147,
#  'researches': 27338,
#  '##urst': 29402,
#  '1997': 2722,
#  '##;': 29628,
#  '##bies': 20536,
#  'tung': 27079,
#  'snuggled': 26867,
#  'toll': 9565,
#  '##广': 30368,
#  'defunct': 11984,
#  'billing': 25640,
#  'ᅦ': 1473,
#  'weeds': 20777,
#  'airways': 13095,
#  '##har': 8167,
#  'stacked': 16934,
#  'sri': 5185,
#  'substituted': 17316,
#  'simplest': 21304,
#  'attempts': 4740,
#  'karma': 19902,
#  'sold': 2853,
#  'issn': 23486,
#  '##gang': 24930,
#  'ingredient': 21774,
#  'akron': 22735,
#  'somerset': 9198,
#  'jude': 12582,
#  '##hli': 27766,
#  'theatre': 3004,
#  'squared': 19942,
#  'priestess': 27677,
#  'accession': 16993,
#  'luz': 26214,
#  'beef': 12486,
#  '##heart': 22375,
#  'mal': 15451,
#  '332': 29327,
#  'ambush': 15283,
#  'horace': 12757,
#  'immense': 14269,
#  'leone': 13363,
#  'manitoba': 10512,
#  '##boarding': 21172,
#  'frontman': 21597,
#  '##skaya': 23070,
#  'averaged': 11398,
#  '[unused647]': 652,
#  '##bino': 21891,
#  '[unused100]': 105,
#  'freestyle': 9817,
#  '##rogen': 22991,
#  '##hesis': 24124,
#  'interpretation': 7613,
#  '##gre': 17603,
#  'epstein': 26646,
#  'customized': 28749,
#  '1651': 29077,
#  '##aday': 28039,
#  'dome': 8514,
#  '##п': 29746,
#  'brussels': 9371,
#  'ago': 3283,
#  'supervised': 13588,
#  '[unused306]': 311,
#  'scarce': 18782,
#  'territory': 3700,
#  'liked': 4669,
#  'entity': 9178,
#  'looted': 27775,
#  'stupidity': 28072,
#  'splitting': 14541,
#  'soaking': 22721,
#  'insistence': 20616,
#  '[unused198]': 203,
#  '1652': 28853,
#  'maharashtra': 12434,
#  '##hol': 14854,
#  'tribes': 6946,
#  'andes': 18096,
#  '##zo': 6844,
#  'jolt': 22538,
#  'orderly': 23589,
#  'dozens': 9877,
#  'indefinite': 25617,
#  'cross': 2892,
#  'smug': 20673,
#  'luciano': 24512,
#  'extant': 12905,
#  '##eson': 21421,
#  'spiritual': 6259,
#  '##oteric': 29112,
#  'batting': 9640,
#  '##aman': 23093,
#  '1972': 3285,
#  'ɕ': 1113,
#  'բ': 1220,
#  'dwarves': 29281,
#  'mint': 12927,
#  'ら': 1685,
#  '##pper': 18620,
#  'ceasefire': 26277,
#  '##tu': 8525,
#  'ч': 1202,
#  'traveler': 20174,
#  'tripoli': 21841,
#  '##tzer': 29546,
#  'beans': 13435,
#  'done': 2589,
#  'jackets': 17764,
#  'pursue': 7323,
#  '##tter': 12079,
#  '##hall': 9892,
#  'plump': 26731,
#  '##я': 17432,
#  'biographies': 22056,
#  '##body': 23684,
#  'expectations': 10908,
#  'slowing': 18068,
#  'kelly': 5163,
#  'explanation': 7526,
#  'pl': 20228,
#  'security': 3036,
#  '[unused568]': 573,
#  '##rda': 13639,
#  'be': 2022,
#  '322': 23768,
#  'beaches': 12212,
#  'di': 4487,
#  'foremost': 16097,
#  'alteration': 26014,
#  'moves': 5829,
#  'organic': 7554,
#  'beers': 18007,
#  'bright': 4408,
#  'raion': 24235,
#  'ச': 1383,
#  'insisted': 7278,
#  'striking': 8478,
#  '##sop': 28793,
#  '##rio': 9488,
#  'airborne': 10519,
#  'halo': 17201,
#  'infections': 15245,
#  '##use': 8557,
#  'paula': 13723,
#  'cooke': 16546,
#  'longest': 6493,
#  'alfa': 22989,
#  '##rch': 11140,
#  'shortened': 12641,
#  'intermittent': 23852,
#  'uefa': 6663,
#  '##タ': 30235,
#  'lucivar': 21401,
#  'sentencing': 23280,
#  'imagine': 5674,
#  'investigative': 15025,
#  '##dalen': 26414,
#  'areas': 2752,
#  'tko': 26537,
#  'planetary': 17700,
#  '##henko': 19767,
#  'aim': 6614,
#  'polytechnic': 14466,
#  'guarded': 13802,
#  'randomly': 18154,
#  '1884': 6988,
#  'groaning': 24781,
#  '…': 1529,
#  'torn': 7950,
#  'solved': 13332,
#  'regulatory': 10738,
#  'convey': 16636,
#  'doorbell': 25422,
#  'dyer': 23494,
#  'rounded': 8352,
#  '##fulness': 20938,
#  'ミ': 1724,
#  'nicole': 9851,
#  'girl': 2611,
#  '##idae': 6096,
#  'purposes': 5682,
#  'their': 2037,
#  'largest': 2922,
#  'references': 7604,
#  'galloway': 22372,
#  'ranged': 15844,
#  'reverted': 16407,
#  'ever': 2412,
#  'posting': 14739,
#  'giving': 3228,
#  'labrador': 18604,
#  'suspense': 23873,
#  'willoughby': 24919,
#  'ascot': 29036,
#  'joaquin': 16877,
#  '##station': 20100,
#  'dea': 26709,
#  'john': 2198,
#  'shade': 8703,
#  'discrete': 16246,
#  'accommodate': 8752,
#  '##ita': 6590,
#  '##astic': 20875,
#  '##aceous': 25560,
#  'contradictory': 27894,
#  '##ng': 3070,
#  'conservation': 5680,
#  'sector': 4753,
#  '##hardt': 13778,
#  '166': 18610,
#  '##ф': 29749,
#  '##shi': 6182,
#  'eric': 4388,
#  'shuddering': 25735,
#  'seventy': 10920,
#  'ellison': 21513,
#  'types': 4127,
#  '##dian': 11692,
#  'alligator': 28833,
#  '[unused70]': 71,
#  'visitation': 28877,
#  '##wright': 26460,
#  'vanuatu': 27625,
#  '##anal': 27953,
#  'infinite': 10709,
#  '##hh': 23644,
#  'nearly': 3053,
#  'spending': 5938,
#  '1911': 5184,
#  'sisters': 5208,
#  'informal': 11900,
#  'yankees': 11081,
#  'usl': 22448,
#  'starters': 29400,
#  'item': 8875,
#  'controls': 7711,
#  'hyun': 21108,
#  'martina': 23508,
#  '##agawa': 20812,
#  '##郎': 30484,
#  '62': 5786,
#  'proton': 20843,
#  '##fers': 24396,
#  'exit': 6164,
#  'firefighters': 21767,
#  '##asse': 27241,
#  'directory': 14176,
#  'rushes': 18545,
#  'eventual': 9523,
#  'bunk': 25277,
#  '##ic': 2594,
#  'seldom': 15839,
#  'venom': 15779,
#  'unprecedented': 15741,
#  'pioneered': 16193,
#  'novelist': 9974,
#  'pantry': 27796,
#  'labs': 13625,
#  'dino': 22412,
#  'cancel': 17542,
#  '##法': 30427,
#  '##cote': 19800,
#  'harta': 26283,
#  'respected': 9768,
#  'shown': 3491,
#  'nasal': 19077,
#  'anthology': 9637,
#  'luck': 6735,
#  '##gill': 19791,
#  '91': 6205,
#  'spp': 26924,
#  '##ב': 29789,
#  '##ও': 29888,
#  'scenario': 11967,
#  'ec': 14925,
#  'trieste': 25199,
#  'ducks': 14875,
#  'persians': 27229,
#  'prevent': 4652,
#  'eased': 10987,
#  'echoes': 17659,
#  '##alia': 22786,
#  '##uaries': 22579,
#  '[unused768]': 773,
#  'tailed': 14578,
#  'going': 2183,
#  'marijuana': 16204,
#  'helped': 3271,
#  'mine': 3067,
#  'hu': 15876,
#  '##itation': 18557,
#  '##tub': 28251,
#  '##ilo': 22360,
#  'annoying': 15703,
#  'cbe': 15852,
#  'cats': 8870,
#  'discontinued': 8944,
#  'sonata': 14681,
#  'rican': 13641,
#  '##区': 30308,
#  'slavic': 13838,
#  'priest': 5011,
#  '978': 4891,
#  'professor': 2934,
#  'provider': 10802,
#  'insignia': 16751,
#  '##gga': 23033,
#  '##dee': 26095,
#  '[unused661]': 666,
#  'cis': 20199,
#  'evie': 26400,
#  'trustee': 13209,
#  '##oue': 27872,
#  'floppy': 28491,
#  'rb': 21144,
#  'obligations': 14422,
#  'ign': 16270,
#  'seahawks': 21390,
#  'extensively': 8077,
#  'growled': 8881,
#  'sheltered': 18304,
#  'irrelevant': 22537,
#  '##cade': 21869,
#  'medications': 20992,
#  'partnership': 5386,
#  'flare': 17748,
#  '##ロ': 30261,
#  '##recht': 28109,
#  'immersion': 27013,
#  'employment': 6107,
#  'gonna': 6069,
#  'hunched': 20498,
#  'shuffled': 18764,
#  '##xide': 19491,
#  'hybrids': 23376,
#  '##tom': 20389,
#  '##ica': 5555,
#  'voivodeship': 7225,
#  'remark': 17674,
#  '##bbing': 23200,
#  'hines': 25445,
#  'manson': 21440,
#  'tran': 25283,
#  'chronicle': 9519,
#  'hysterical': 25614,
#  'protesting': 21248,
#  'implant': 27159,
#  '##།': 29961,
#  'ministerial': 18645,
#  'few': 2261,
#  'ipa': 24531,
#  'limitation': 22718,
#  'newer': 10947,
#  'songwriting': 14029,
#  'litigation': 15382,
#  'agree': 5993,
#  'edison': 17046,
#  'atrium': 26204,
#  'regarding': 4953,
#  'gather': 8587,
#  'covered': 3139,
#  'compared': 4102,
#  'unspoken': 25982,
#  'rink': 18416,
#  'armada': 25306,
#  'novak': 19580,
#  'occupied': 4548,
#  'affirmed': 19768,
#  'william': 2520,
#  'connection': 4434,
#  'wisdom': 9866,
#  '##ه': 14157,
#  '##下': 30269,
#  'scaled': 18953,
#  '##ow': 5004,
#  'worries': 15508,
#  'huddersfield': 19715,
#  'mounted': 5614,
#  'originating': 14802,
#  'luminous': 25567,
#  'parades': 26635,
#  'char': 25869,
#  'corner': 3420,
#  'generations': 8213,
#  'cyber': 16941,
#  'whitman': 21311,
#  '[unused854]': 859,
#  'continued': 2506,
#  'overtime': 12253,
#  'teatro': 16038,
#  'hoover': 17443,
#  'bari': 22466,
#  '##spar': 27694,
#  'below': 2917,
#  'quota': 20563,
#  '##ya': 3148,
#  'burst': 6532,
#  'trained': 4738,
#  'quit': 8046,
#  'user': 5310,
#  'concerts': 6759,
#  'cultivated': 13237,
#  '##∅': 30121,
#  '##rte': 19731,
#  'una': 14477,
#  'barron': 23594,
#  'bean': 14068,
#  'vinyl': 8877,
#  'themed': 11773,
#  '##ners': 16912,
#  '##deh': 25383,
#  'asserted': 13647,
#  '##tad': 17713,
#  '##hett': 28499,
#  'companies': 3316,
#  '##phs': 18757,
#  'bacterial': 17341,
#  '##utter': 26878,
#  'connie': 16560,
#  'antique': 14361,
#  'kunst': 28145,
#  'militias': 29271,
#  '1741': 25280,
#  '[unused527]': 532,
#  'wil': 19863,
#  'emile': 17127,
#  'mig': 19117,
#  'inserted': 12889,
#  'laurent': 14718,
#  'lent': 15307,
#  'shale': 18488,
#  '##stad': 16917,
#  'bn': 24869,
#  'cannes': 14775,
#  'elects': 27161,
#  'duluth': 28218,
#  'arms': 2608,
#  '##lah': 14431,
#  'fortunes': 18023,
#  'iron': 3707,
#  'stimulating': 27295,
#  'deployment': 10813,
#  'vacancy': 15619,
#  'adept': 26398,
#  'charges': 5571,
#  'ease': 7496,
#  'condemning': 28525,
#  '##tri': 18886,
#  'bolivia': 11645,
#  '##rey': 15202,
#  'montrose': 24990,
#  '[unused393]': 398,
#  '##rong': 17583,
#  'craven': 21232,
#  '1623': 29056,
#  '1926': 4881,
#  '##ほ': 30202,
#  'rapid': 5915,
#  'urging': 14328,
#  'curses': 23897,
#  'fated': 27442,
#  'luzon': 21622,
#  'sax': 19656,
#  'backwards': 11043,
#  '英': 1941,
#  'far': 2521,
#  'visits': 7879,
#  'omega': 14827,
#  '##lide': 24198,
#  'twigs': 27964,
#  'gmbh': 18289,
#  '1643': 25534,
#  'visionary': 28036,
#  '##kei': 29501,
#  'manufacture': 9922,
#  'excelled': 23081,
#  'spotlight': 17763,
#  'extensive': 4866,
#  'yank': 23178,
#  'think': 2228,
#  'thus': 2947,
#  'anticipated': 11436,
#  '##cous': 27199,
#  'poet': 4802,
#  'gravel': 11127,
#  'cup': 2452,
#  'silenced': 25030,
#  'proclamation': 16413,
#  'conviction': 10652,
#  '##⽥': 30160,
#  '##অ': 29883,
#  'lacrosse': 13488,
#  'liv': 22135,
#  'selangor': 28904,
#  '##ষ': 29911,
#  'polynomial': 17505,
#  'disadvantage': 20502,
#  'lifeless': 22185,
#  '##yp': 22571,
#  '##gly': 25643,
#  '##ward': 7652,
#  'amounted': 18779,
#  'न': 1327,
#  '##bound': 15494,
#  'evolution': 6622,
#  '##sum': 17421,
#  'recalled': 7383,
#  'camping': 13215,
#  '##phones': 19093,
#  'ا': 1270,
#  'flashback': 21907,
#  '##pre': 28139,
#  '##rso': 25301,
#  '##dah': 18417,
#  'flights': 7599,
#  'diver': 17856,
#  '##ip': 11514,
#  'periodic': 15861,
#  'otter': 22279,
#  '##omic': 22026,
#  'carla': 17081,
#  '[unused802]': 807,
#  'castillo': 19371,
#  'tactic': 19717,
#  'violate': 23640,
#  'caressing': 25296,
#  'ე': 1442,
#  'branch': 3589,
#  'airfield': 9087,
#  'anybody': 10334,
#  'parenting': 28586,
#  'plasma': 12123,
#  'biplane': 28686,
#  'noted': 3264,
#  'andrea': 8657,
#  'flu': 19857,
#  'sipping': 24747,
#  'lines': 3210,
#  'caucasian': 23368,
#  '##gens': 21230,
#  'repair': 7192,
#  '##shaw': 17980,
#  '57th': 28623,
#  '##lk': 13687,
#  'freyja': 7075,
#  'finished': 2736,
#  'merged': 5314,
#  'mallory': 20468,
#  'climatic': 27301,
#  'nike': 18368,
#  'zinc': 15813,
#  'pod': 17491,
#  'portuguese': 5077,
#  'anyone': 3087,
#  'championships': 3219,
#  'brakes': 13627,
#  'monastic': 17361,
#  'henley': 20768,
#  '##redo': 23417,
#  'distributed': 5500,
#  '##zbek': 28733,
#  'spin': 6714,
#  '160': 8148,
#  '##break': 23890,
#  'sa': 7842,
#  '##imov': 25299,
#  'dances': 11278,
#  'hind': 17666,
#  'streetcar': 21420,
#  '[unused433]': 438,
#  'guam': 16162,
#  'opus': 16895,
#  'serbian': 6514,
#  'doctor': 3460,
#  'mustered': 21900,
#  '##kla': 26086,
#  'reassigned': 18026,
#  'blanco': 20036,
#  'general': 2236,
#  'annexed': 13291,
#  'passageway': 27336,
#  'transaction': 12598,
#  'adjust': 14171,
#  'radiated': 23000,
#  '[unused23]': 24,
#  'expressway': 11720,
#  'white': 2317,
#  'andersson': 28643,
#  '##gler': 17420,
#  'pollock': 25218,
#  '##taro': 28160,
#  'payton': 28666,
#  '₂': 1549,
#  'tingling': 23690,
#  'posted': 6866,
#  'anxiously': 23403,
#  '##omy': 16940,
#  '33rd': 20883,
#  'chun': 20979,
#  '##sel': 11246,
#  '##arians': 28369,
#  '##udence': 29424,
#  'caine': 19881,
#  'ask': 3198,
#  'increase': 3623,
#  'stake': 8406,
#  '##し': 30183,
#  'filippo': 28669,
#  'residential': 5647,
#  'stated': 3090,
#  '##raße': 27807,
#  'involvement': 6624,
#  '1827': 12309,
#  'k': 1047,
#  'sons': 4124,
#  '##kins': 14322,
#  'heats': 18559,
#  'shivered': 13927,
#  '[unused664]': 669,
#  'њ': 1216,
#  'mangrove': 29340,
#  '##llon': 22179,
#  '##ᄎ': 30001,
#  '##ulio': 24825,
#  'domed': 29208,
#  'interrogation': 16871,
#  'unfair': 15571,
#  '##mm': 7382,
#  '1784': 16496,
#  'predictable': 21425,
#  'yamaha': 24031,
#  'reported': 2988,
#  'becoming': 3352,
#  'crossbow': 28692,
#  '##storm': 19718,
#  '[unused371]': 376,
#  'forces': 2749,
#  'novgorod': 24338,
#  'title': 2516,
#  'japan': 2900,
#  '##rring': 18807,
#  'clasp': 23465,
#  'verb': 12034,
#  '133': 14506,
#  'burnett': 13829,
#  '##zam': 20722,
#  'whip': 11473,
#  'spanish': 3009,
#  'band': 2316,
#  '##千': 30310,
#  'grandmother': 7133,
#  '-': 1011,
#  '##yam': 14852,
#  'customs': 8205,
#  'place': 2173,
#  'statesman': 17689,
#  '##edging': 28002,
#  '##ink': 19839,
#  'brew': 24702,
#  'palestine': 8976,
#  'competed': 3879,
#  'advancement': 12607,
#  '##pw': 28400,
#  'schumann': 29448,
#  'umpire': 20887,
#  'variants': 10176,
#  'gonzales': 24334,
#  'players': 2867,
#  '##nical': 20913,
#  'becca': 22140,
#  '##rran': 28327,
#  'balcony': 11673,
#  '##type': 13874,
#  'julio': 15090,
#  'libraries': 8860,
#  '[unused809]': 814,
#  'satisfying': 17087,
#  'constable': 12294,
#  'cub': 21987,
#  'storylines': 22628,
#  '236': 23593,
#  'prism': 26113,
#  '##ு': 29933,
#  'nec': 26785,
#  'kaufman': 23699,
#  'accredited': 11459,
#  'characterization': 23191,
#  'cousins': 12334,
#  '[unused150]': 155,
#  'emmy': 10096,
#  'salad': 16521,
#  '##koto': 24886,
#  '##テ': 30239,
#  'ammonia': 25874,
#  '##ea': 5243,
#  'drink': 4392,
#  '[unused13]': 14,
#  '175': 12862,
#  '##olio': 29401,
#  '##aling': 21682,
#  'fatal': 10611,
#  'patented': 16719,
#  '[unused71]': 72,
#  '##oration': 21223,
#  '##cker': 9102,
#  'deaths': 6677,
#  'stores': 5324,
#  'wheel': 5217,
#  '##dit': 23194,
#  'tammy': 19971,
#  'receptions': 16466,
#  'norway': 5120,
#  'spouse': 18591,
#  'exclude': 23329,
#  'saturday': 5095,
#  'sergey': 22703,
#  'commissions': 13239,
#  '##十': 30309,
#  '神': 1925,
#  '##bic': 13592,
#  'neared': 20832,
#  'hurriedly': 23878,
#  'admit': 6449,
#  '##zzle': 17644,
#  'replacement': 6110,
#  'dammit': 20878,
#  'dialed': 21300,
#  'protestants': 19592,
#  'embarrassment': 14325,
#  'truly': 5621,
#  'involved': 2920,
#  'perfectly': 6669,
#  '[unused20]': 21,
#  'fulfill': 13883,
#  'cardiac': 15050,
#  'perch': 21836,
#  'silvia': 27827,
#  'roots': 6147,
#  'earl': 4656,
#  'milton': 9660,
#  'csa': 27804,
#  'encoding': 17181,
#  'differentiation': 20582,
#  'gloss': 27068,
#  '306': 24622,
#  'fling': 27655,
#  'fruits': 10962,
#  'este': 28517,
#  '[unused31]': 32,
#  'properly': 7919,
#  'treasurer': 10211,
#  'estonian': 12029,
#  'sings': 10955,
#  'ulster': 11059,
#  'cesar': 14923,
#  'sterile': 25403,
#  '##(': 29619,
#  'burgundy': 18383,
#  'backyard': 16125,
#  'seneca': 21224,
#  'massage': 21881,
#  'drown': 19549,
#  'via': 3081,
#  'spaces': 7258,
#  'intends': 18754,
#  'phone': 3042,
#  '[unused847]': 852,
#  'parentheses': 27393,
#  'colombian': 13598,
#  'rush': 5481,
#  'screening': 11326,
#  'medicare': 27615,
#  'oils': 20631,
#  '##zek': 24506,
#  'diversion': 20150,
#  'witchcraft': 21599,
#  'appointing': 28050,
#  'group': 2177,
#  'pennsylvania': 3552,
#  '##tain': 18249,
#  '##tooth': 19392,
#  'appropriations': 22713,
#  'somehow': 5064,
#  'superhero': 16251,
#  'international': 2248,
#  '[unused400]': 405,
#  '##nson': 15551,
#  'shankar': 17429,
#  'siberian': 21822,
#  '##den': 4181,
#  'implying': 20242,
#  'salzburg': 18369,
#  'bowls': 15220,
#  'richards': 9712,
#  'ike': 25209,
#  'pardon': 14933,
#  'blackpool': 17444,
#  '##uring': 12228,
#  'tin': 9543,
#  'mueller': 26774,
#  'tricked': 24929,
#  'wouldn': 2876,
#  'lisa': 7059,
#  'riot': 11421,
#  'broncos': 14169,
#  '##ghi': 28891,
#  '##12': 12521,
#  '08': 5511,
#  'infused': 29592,
#  'implementation': 7375,
#  'smirk': 15081,
#  '##rdon': 28176,
#  '##keepers': 24764,
#  '弘': 1843,
#  '##inate': 14776,
#  '##ory': 10253,
#  '∩': 1604,
#  'villagers': 11904,
#  'alvarez': 16309,
#  '##av': 11431,
#  'hellenic': 23122,
#  '##zan': 13471,
#  '##gers': 15776,
#  'answered': 4660,
#  'groundbreaking': 23222,
#  'prank': 26418,
#  '##nche': 26091,
#  'ᵗ': 1505,
#  'programmers': 28547,
#  '[unused49]': 50,
#  'biblical': 10213,
#  'imaging': 12126,
#  'amos': 13744,
#  ...}

# %% [markdown]
# # Load dataset with cache

# %%
from datasets import load_dataset

# %%
dataset = load_dataset('wikitext', 'wikitext-2-raw-v1', cache_dir='cache_datasets/datasets')
# Out:
# Downloading and preparing dataset wikitext/wikitext-2-raw-v1 to /home/namch_hust1_gmail_com/cache_datasets/datasets/wikitext/wikitext-2-raw-v1/1.0.0/a241db52902eaf2c6aa732210bead40c090019a499ceb13bcbfa3f8ab646a126...
# Downloading data:   0%|          | 0.00/4.72M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/4358 [00:00<?, ? examples/s]
# Generating train split:   0%|          | 0/36718 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/3760 [00:00<?, ? examples/s]
# Dataset wikitext downloaded and prepared to /home/namch_hust1_gmail_com/cache_datasets/datasets/wikitext/wikitext-2-raw-v1/1.0.0/a241db52902eaf2c6aa732210bead40c090019a499ceb13bcbfa3f8ab646a126. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['text'],
#         num_rows: 4358
#     })
#     train: Dataset({
#         features: ['text'],
#         num_rows: 36718
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 3760
#     })
# })

# %%
dataset['train'][2]
# Out:
# {'text': ''}

# %%
print(1)
# Out:
# 1
